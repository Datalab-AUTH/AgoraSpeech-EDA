# %% [markdown]
# This notebook computes the descriptive statistics of the metadata and human annotations.
#
# * Input: 'AgoraSpeech_preprocessed.csv'
# * Output: prints
# * Actions: For the entire dataset and per individual politician, it computes:
#     1. Total number of speeches
#     2. Total number of paragraphs
#     3. Total number of words
#     4. Average paragraphs per speech
#     5. Average words per speech
#     6. Average words per paragraph
#     7. Percentage of paragraphs identified as 'criticism'
#     8. Percentage of paragraphs identified as 'political agenda'
#     9. Sum of unique topics of all speeches
#     10. Average of unique topics per speech
#     11. Average sentiment score of all speeches
#     12. Average sentiment score per speech
#     13. Average polarization score of all speeches
#     14. Average polarization score per speech
#     15. Average populism score of all speeches
#     16. Average populism score per speech
#     17. Sum of unique entities of all speeches
#     18. Average of unique entities per speech
#     19. Average of unique entities per paragraph

# %%
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
from descriptive_statistics_functions import *

# %%
# read the preprocessed data
data = pd.read_csv('AgoraSpeech_preprocessed.csv')

# %% [markdown]
# Descriptive statistics for the entire dataset

# %%
print(f"Statistics for the overall dataset ... ")
all_statistics(data, overall=True)
# Out:
# Statistics for the overall dataset ...
# General statistics:
# -------------------
# total number of speeches:  171
# total number of paragraphs:  5279
# total number of words:  717718
# avg paragraphs per speech:  30.87
# avg words per speech  4197.18
# avg words per paragraph:  135.96
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.6098
# criticism percentage:  0.3902
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  33
# avg_of_unique_topics_of_per_speech:  12.53
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  0.03
# sentiment_avg_per_speech:  0.01
# polarization_avg:  0.16
# polarization_avg_per_speech:  0.16
# populism_avg:  0.07
# populism_avg_per_speech:  0.07
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  7763
# avg of unique entities per speech:  122.61
# avg of unique entities per paragraph:  5.66

# %% [markdown]
# Descriptive statistics per individual politician

# %%
for politician in data['politician'].unique():
    politician_df = data[data['politician'] == politician]
    print(f"Statistics for {politician} ... ")
    all_statistics(politician_df)
    print("\n")
# Out:
# Statistics for Androulakis ...
# General statistics:
# -------------------
# total number of speeches:  26
# total number of paragraphs:  883
# total number of words:  132620
# avg paragraphs per speech:  33.96
# avg words per speech  5100.77
# avg words per paragraph:  150.19
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.6025
# criticism percentage:  0.3975
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  32
# avg_of_unique_topics_of_per_speech:  15.58
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  0.0
# sentiment_avg_per_speech:  -0.01
# polarization_avg:  0.17
# polarization_avg_per_speech:  0.16
# populism_avg:  0.09
# populism_avg_per_speech:  0.09
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  1605
# avg of unique entities per speech:  137.92
# avg of unique entities per paragraph:  6.51
#
#
# Statistics for Koutsoumpas ...
# General statistics:
# -------------------
# total number of speeches:  27
# total number of paragraphs:  707
# total number of words:  98807
# avg paragraphs per speech:  26.19
# avg words per speech  3659.52
# avg words per paragraph:  139.76
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.5248
# criticism percentage:  0.4752
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  31
# avg_of_unique_topics_of_per_speech:  9.85
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  -0.25
# sentiment_avg_per_speech:  -0.25
# polarization_avg:  0.26
# polarization_avg_per_speech:  0.26
# populism_avg:  0.11
# populism_avg_per_speech:  0.12
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  1531
# avg of unique entities per speech:  104.96
# avg of unique entities per paragraph:  5.97
#
#
# Statistics for Mitsotakis ...
# General statistics:
# -------------------
# total number of speeches:  45
# total number of paragraphs:  1385
# total number of words:  147709
# avg paragraphs per speech:  30.78
# avg words per speech  3282.42
# avg words per paragraph:  106.65
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.8491
# criticism percentage:  0.1509
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  31
# avg_of_unique_topics_of_per_speech:  12.47
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  0.46
# sentiment_avg_per_speech:  0.49
# polarization_avg:  0.07
# polarization_avg_per_speech:  0.07
# populism_avg:  0.02
# populism_avg_per_speech:  0.02
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  2050
# avg of unique entities per speech:  99.96
# avg of unique entities per paragraph:  4.51
#
#
# Statistics for Tsipras ...
# General statistics:
# -------------------
# total number of speeches:  44
# total number of paragraphs:  1601
# total number of words:  185139
# avg paragraphs per speech:  36.39
# avg words per speech  4207.7
# avg words per paragraph:  115.64
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.5353
# criticism percentage:  0.4647
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  31
# avg_of_unique_topics_of_per_speech:  13.89
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  -0.05
# sentiment_avg_per_speech:  -0.06
# polarization_avg:  0.16
# polarization_avg_per_speech:  0.16
# populism_avg:  0.09
# populism_avg_per_speech:  0.09
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  2597
# avg of unique entities per speech:  129.84
# avg of unique entities per paragraph:  4.99
#
#
# Statistics for Varoufakis ...
# General statistics:
# -------------------
# total number of speeches:  18
# total number of paragraphs:  525
# total number of words:  124716
# avg paragraphs per speech:  29.17
# avg words per speech  6928.67
# avg words per paragraph:  237.55
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.5086
# criticism percentage:  0.4914
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  28
# avg_of_unique_topics_of_per_speech:  11.0
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  -0.27
# sentiment_avg_per_speech:  -0.29
# polarization_avg:  0.18
# polarization_avg_per_speech:  0.18
# populism_avg:  0.09
# populism_avg_per_speech:  0.09
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  1911
# avg of unique entities per speech:  192.67
# avg of unique entities per paragraph:  8.53
#
#
# Statistics for Velopoulos ...
# General statistics:
# -------------------
# total number of speeches:  11
# total number of paragraphs:  178
# total number of words:  28727
# avg paragraphs per speech:  16.18
# avg words per speech  2611.55
# avg words per paragraph:  161.39
# Criticism vs agenda percentages:
# --------------------------------
# agenda percentage:  0.7135
# criticism percentage:  0.2865
# Topics statistics:
# ------------------
# sum_of_unique_topics_of_all_speeches:  27
# avg_of_unique_topics_of_per_speech:  9.18
# Sentiment, polarization and populsim statistics:
# ------------------------------------------------
# sentiment_avg:  -0.44
# sentiment_avg_per_speech:  -0.44
# polarization_avg:  0.2
# polarization_avg_per_speech:  0.21
# populism_avg:  0.05
# populism_avg_per_speech:  0.05
# Entities statistics:
# --------------------
# sum of unique entities of all speeches:  600
# avg of unique entities per speech:  78.91
# avg of unique entities per paragraph:  6.74
